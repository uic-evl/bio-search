# %%
import matplotlib.pyplot as plt

x = [50000, 100000, 
150000,
200000,
250000,
300000,
350000,
400000,
450000,
500000,
550000,
600000,
872571]

y = [
10.02,
19.4,
42.57,
74.66,
114.02,
161.18,
222.43,
284.56,
368.88,
447.78,
546.87,
569.78,
1260
]

# %%
plt.plot(x, y)
