# %%
import pandas as pd

modalities_filepath = 'all.parquet'
cord_filepath = '2022-02-07-cord19.parquet'

modalities_df = pd.read_parquet(modalities_filepath)
cord_df = pd.read_parquet(cord_filepath)

# %%
modalities_df.tail()
# Out:
#                                                       img label caption  \
# 524134  PMC7153745supplementaryfigsplit_978-90-368-111...  None
# 524135  PMC7153745supplementaryfigsplit_978-90-368-111...  None
# 524136  PMC7153745supplementaryfigsplit_978-90-368-111...  None
# 524137  PMC7153745supplementaryfigsplit_978-90-368-111...  None
# 524138  PMC7153745supplementaryfigsplit_978-90-368-111...  None
#
#         width  height prediction  \
# 524134   1300     346        gra
# 524135   2026    1180        oth
# 524136    968     833    gra.his
# 524137    961     353        oth
# 524138    961     366        mol
#
#                                                  img_path
# 524134  cord19-uic/PMC7153745/supplementary/figsplit_9...
# 524135  cord19-uic/PMC7153745/supplementary/figsplit_9...
# 524136  cord19-uic/PMC7153745/supplementary/figsplit_9...
# 524137  cord19-uic/PMC7153745/supplementary/figsplit_9...
# 524138  cord19-uic/PMC7153745/supplementary/figsplit_9...

# %% [markdown]
# # Create a dictionary of modalities with PMCID as key

# %%
modalities_df.reset_index()
pmc_modalities_df = modalities_df[modalities_df.img_path.str.contains('cord19-uic')]
pmc_modalities_df['pmcid'] = pmc_modalities_df.apply(lambda x: x.img_path.split('/')[1], axis=1)
grouped = pmc_modalities_df.groupby('pmcid')['prediction']
modalities_dict = { x: list(y.values) for x, y in grouped}

# there are books in the collection!!!
# print(len(modalities_dict['PMC7153745']))
# Out:
# <ipython-input-67-701f42362f49>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pmc_modalities_df['pmcid'] = pmc_modalities_df.apply(lambda x: x.img_path.split('/')[1], axis=1)

# %% [markdown]
# # Join arrays in the dataframe

# %%
def get_modalities(pmcid, mod_dict):
  if pmcid in mod_dict:
    return ' '.join(mod_dict[pmcid])
  else:
    return ''

cord_df['modalities'] = cord_df.apply(lambda x: get_modalities(x.pmcid, modalities_dict), axis=1)

# %%
keys_modalities = set(modalities_dict.keys())
keys_cord = set(list(cord_df.pmcid.values))

intersection = keys_modalities.intersection(keys_cord)
intersection
# Out:
# {'PMC7114679',
#  'PMC7129684',
#  'PMC5035956',
#  'PMC7109999',
#  'PMC7117007',
#  'PMC6439455',
#  'PMC7106367',
#  'PMC7126179',
#  'PMC7126208',
#  'PMC7140268',
#  'PMC1087510',
#  'PMC7108202',
#  'PMC7111915',
#  'PMC7153742',
#  'PMC6291621',
#  'PMC6201323',
#  'PMC6981968',
#  'PMC2682425',
#  'PMC5801420',
#  'PMC5127025',
#  'PMC7125693',
#  'PMC7120794',
#  'PMC7105191',
#  'PMC7149799',
#  'PMC7108074',
#  'PMC7115380',
#  'PMC6999894',
#  'PMC5896402',
#  'PMC7086586',
#  'PMC6348445',
#  'PMC6057575',
#  'PMC7122368',
#  'PMC1559929',
#  'PMC7103344',
#  'PMC7123404',
#  'PMC2912257',
#  'PMC7130735',
#  'PMC7112831',
#  'PMC7122034',
#  'PMC7035790',
#  'PMC7117015',
#  'PMC7112051',
#  'PMC7112888',
#  'PMC6466079',
#  'PMC4644801',
#  'PMC7127015',
#  'PMC7106405',
#  'PMC7125814',
#  'PMC4690872',
#  'PMC5035509',
#  'PMC7124226',
#  'PMC7125908',
#  'PMC6304313',
#  'PMC7110128',
#  'PMC6758846',
#  'PMC3407925',
#  'PMC3356205',
#  'PMC2843722',
#  'PMC3978084',
#  'PMC7111801',
#  'PMC7094655',
#  'PMC7120199',
#  'PMC3155236',
#  'PMC5979549',
#  'PMC3589764',
#  'PMC3542382',
#  'PMC7122237',
#  'PMC2885389',
#  'PMC7126292',
#  'PMC4240815',
#  'PMC7088669',
#  'PMC7148649',
#  'PMC7087851',
#  'PMC4483639',
#  'PMC5109928',
#  'PMC7148899',
#  'PMC7112524',
#  'PMC4014123',
#  'PMC7127363',
#  'PMC7118342',
#  'PMC6963679',
#  'PMC6009590',
#  'PMC5659040',
#  'PMC7088578',
#  'PMC7125848',
#  'PMC7122547',
#  'PMC7126139',
#  'PMC6364421',
#  'PMC7115257',
#  'PMC7118453',
#  'PMC7087186',
#  'PMC2779851',
#  'PMC3280993',
#  'PMC3871797',
#  'PMC6071288',
#  'PMC6893519',
#  'PMC7107470',
#  'PMC7112620',
#  'PMC5719735',
#  'PMC6537705',
#  'PMC7111757',
#  'PMC7097370',
#  'PMC4746320',
#  'PMC6016250',
#  'PMC5386261',
#  'PMC7119823',
#  'PMC7127381',
#  'PMC7094555',
#  'PMC3528286',
#  'PMC5589259',
#  'PMC7126981',
#  'PMC7121234',
#  'PMC2723768',
#  'PMC7089108',
#  'PMC4894584',
#  'PMC7142675',
#  'PMC7123574',
#  'PMC4019513',
#  'PMC2982091',
#  'PMC5881172',
#  'PMC7108107',
#  'PMC7124225',
#  'PMC7087847',
#  'PMC6315164',
#  'PMC5546975',
#  'PMC6659655',
#  'PMC5388297',
#  'PMC7106226',
#  'PMC3713824',
#  'PMC7086634',
#  'PMC7111307',
#  'PMC7108207',
#  'PMC7149803',
#  'PMC4442129',
#  'PMC6501061',
#  'PMC7091805',
#  'PMC7094245',
#  'PMC6438514',
#  'PMC7129466',
#  'PMC7112536',
#  'PMC7094473',
#  'PMC4878077',
#  'PMC7107804',
#  'PMC3715556',
#  'PMC3442825',
#  'PMC7112846',
#  'PMC7123373',
#  'PMC5362848',
#  'PMC1783898',
#  'PMC6200245',
#  'PMC6399136',
#  'PMC7106520',
#  'PMC7104923',
#  'PMC7107222',
#  'PMC5052842',
#  'PMC4655210',
#  'PMC2633348',
#  'PMC7115297',
#  'PMC7128581',
#  'PMC7092892',
#  'PMC7087191',
#  'PMC5583225',
#  'PMC6832442',
#  'PMC6982925',
#  'PMC3291373',
#  'PMC3989048',
#  'PMC7091640',
#  'PMC4305246',
#  'PMC7117285',
#  'PMC7127555',
#  'PMC3199250',
#  'PMC7086528',
#  'PMC7112317',
#  'PMC6487761',
#  'PMC7125691',
#  'PMC7107243',
#  'PMC3017695',
#  'PMC4494211',
#  'PMC5587679',
#  'PMC7086645',
#  'PMC6626354',
#  'PMC7090665',
#  'PMC7144421',
#  'PMC4340788',
#  'PMC4631062',
#  'PMC5567209',
#  'PMC7110605',
#  'PMC7117092',
#  'PMC6315912',
#  'PMC7150019',
#  'PMC4534143',
#  'PMC2213648',
#  'PMC6604760',
#  'PMC3977202',
#  'PMC7094489',
#  'PMC7123453',
#  'PMC1636451',
#  'PMC6117962',
#  'PMC7090476',
#  'PMC1525181',
#  'PMC3848732',
#  'PMC4976375',
#  'PMC4033992',
#  'PMC4341224',
#  'PMC7086817',
#  'PMC7107308',
#  'PMC4447251',
#  'PMC7131330',
#  'PMC7135705',
#  'PMC3446766',
#  'PMC5673231',
#  'PMC7094490',
#  'PMC4686887',
#  'PMC7096732',
#  'PMC6256373',
#  'PMC7103684',
#  'PMC7121709',
#  'PMC4424121',
#  'PMC3925807',
#  'PMC2935601',
#  'PMC5503262',
#  'PMC7089486',
#  'PMC7148911',
#  'PMC7125761',
#  'PMC3185727',
#  'PMC6234657',
#  'PMC7087261',
#  'PMC7126120',
#  'PMC7123098',
#  'PMC6963926',
#  'PMC3761238',
#  'PMC6616404',
#  'PMC4085092',
#  'PMC5481143',
#  'PMC5240764',
#  'PMC7102729',
#  'PMC7114363',
#  'PMC4880069',
#  'PMC5449628',
#  'PMC6422942',
#  'PMC5070814',
#  'PMC7135639',
#  'PMC7127151',
#  'PMC7112692',
#  'PMC5069610',
#  'PMC7095127',
#  'PMC7118982',
#  'PMC7125662',
#  'PMC6274228',
#  'PMC7109898',
#  'PMC7127475',
#  'PMC7115665',
#  'PMC7120684',
#  'PMC7094442',
#  'PMC7111882',
#  'PMC7114313',
#  'PMC4687909',
#  'PMC7091181',
#  'PMC4775799',
#  'PMC5847970',
#  'PMC7128301',
#  'PMC7124434',
#  'PMC5382377',
#  'PMC5325537',
#  'PMC4982171',
#  'PMC7135029',
#  'PMC7123665',
#  'PMC3952398',
#  'PMC7148998',
#  'PMC7127509',
#  'PMC7128826',
#  'PMC5930744',
#  'PMC7121534',
#  'PMC7089115',
#  'PMC7094303',
#  'PMC7126104',
#  'PMC3753329',
#  'PMC7112625',
#  'PMC5536730',
#  'PMC7115656',
#  'PMC6238701',
#  'PMC3376813',
#  'PMC7152024',
#  'PMC3149051',
#  'PMC7094366',
#  'PMC2764123',
#  'PMC7127648',
#  'PMC7144807',
#  'PMC7094169',
#  'PMC7122293',
#  'PMC7121663',
#  'PMC3901494',
#  'PMC6893414',
#  'PMC7125803',
#  'PMC7080110',
#  'PMC7088015',
#  'PMC7115642',
#  'PMC6302599',
#  'PMC6305387',
#  'PMC6523588',
#  'PMC5446561',
#  'PMC7117022',
#  'PMC3892273',
#  'PMC5882653',
#  'PMC5109407',
#  'PMC5903617',
#  'PMC3383332',
#  'PMC7033854',
#  'PMC7123570',
#  'PMC7126170',
#  'PMC7127434',
#  'PMC2770056',
#  'PMC7105212',
#  'PMC4318943',
#  'PMC7129252',
#  'PMC4420464',
#  'PMC7114494',
#  'PMC6691355',
#  'PMC7115663',
#  'PMC7119573',
#  'PMC3427170',
#  'PMC4652064',
#  'PMC5784731',
#  'PMC7134569',
#  'PMC6754309',
#  'PMC7124316',
#  'PMC7121080',
#  'PMC7120071',
#  'PMC7126852',
#  'PMC4402537',
#  'PMC7127224',
#  'PMC7131451',
#  'PMC7113661',
#  'PMC4119655',
#  'PMC7119690',
#  'PMC7112095',
#  'PMC7097645',
#  'PMC4034481',
#  'PMC7112581',
#  'PMC7118894',
#  'PMC7105048',
#  'PMC5462650',
#  'PMC7125680',
#  'PMC7128705',
#  'PMC3492083',
#  'PMC7117394',
#  'PMC4920747',
#  'PMC6784089',
#  'PMC7124279',
#  'PMC7150009',
#  'PMC4219353',
#  'PMC5155576',
#  'PMC7088141',
#  'PMC6806761',
#  'PMC3663648',
#  'PMC6336914',
#  'PMC7094744',
#  'PMC7121250',
#  'PMC2387173',
#  'PMC7112007',
#  'PMC3289638',
#  'PMC5932059',
#  'PMC7106350',
#  'PMC3572654',
#  'PMC1888488',
#  'PMC5665538',
#  'PMC6811514',
#  'PMC7080032',
#  'PMC3293464',
#  'PMC6108254',
#  'PMC7088358',
#  'PMC3446906',
#  'PMC6473159',
#  'PMC7118720',
#  'PMC4389414',
#  'PMC4652763',
#  'PMC4942116',
#  'PMC7089579',
#  'PMC5124117',
#  'PMC7087010',
#  'PMC7094562',
#  'PMC5790926',
#  'PMC7116953',
#  'PMC5330215',
#  'PMC6663624',
#  'PMC7143988',
#  'PMC5989030',
#  'PMC7107241',
#  'PMC6405118',
#  'PMC7107189',
#  'PMC7110351',
#  'PMC5380771',
#  'PMC4829504',
#  'PMC7088030',
#  'PMC6190172',
#  'PMC3706975',
#  'PMC7122392',
#  'PMC7121376',
#  'PMC7086749',
#  'PMC4582189',
#  'PMC7114323',
#  'PMC7119049',
#  'PMC7127754',
#  'PMC7127220',
#  'PMC2989007',
#  'PMC7096728',
#  'PMC4715219',
#  'PMC2396482',
#  'PMC6531879',
#  'PMC5059946',
#  'PMC7134607',
#  'PMC7149772',
#  'PMC2483296',
#  'PMC6530530',
#  'PMC7097743',
#  'PMC5010982',
#  'PMC1606622',
#  'PMC3520906',
#  'PMC6598183',
#  'PMC7124263',
#  'PMC7150029',
#  'PMC7103277',
#  'PMC7127432',
#  'PMC7091900',
#  'PMC7111310',
#  'PMC7115022',
#  'PMC4634274',
#  'PMC7088033',
#  'PMC7115419',
#  'PMC7130949',
#  'PMC7117017',
#  'PMC4169035',
#  'PMC6009648',
#  'PMC4957826',
#  'PMC6063423',
#  'PMC3580775',
#  'PMC7110787',
#  'PMC5450902',
#  'PMC3928306',
#  'PMC3783221',
#  'PMC6921433',
#  'PMC4374484',
#  'PMC7087572',
#  'PMC7131806',
#  'PMC7080170',
#  'PMC4902778',
#  'PMC7107264',
#  'PMC5893744',
#  'PMC7134523',
#  'PMC7088819',
#  'PMC7046817',
#  'PMC3492009',
#  'PMC7087294',
#  'PMC7123343',
#  'PMC7130876',
#  'PMC4918144',
#  'PMC7110670',
#  'PMC7149649',
#  'PMC5112662',
#  'PMC7114822',
#  'PMC7150040',
#  'PMC7111177',
#  'PMC3670673',
#  'PMC7111987',
#  'PMC6466025',
#  'PMC5454426',
#  'PMC7097571',
#  'PMC5253144',
#  'PMC7127405',
#  'PMC6743247',
#  'PMC5587294',
#  'PMC7114112',
#  'PMC7094133',
#  'PMC3016318',
#  'PMC6713929',
#  'PMC3240602',
#  'PMC3293463',
#  'PMC7105062',
#  'PMC5653245',
#  'PMC4462091',
#  'PMC7117346',
#  'PMC6829326',
#  'PMC7094233',
#  'PMC7120317',
#  'PMC3427675',
#  'PMC7111781',
#  'PMC7117519',
#  'PMC7096617',
#  'PMC5855786',
#  'PMC7113646',
#  'PMC4857328',
#  'PMC7120578',
#  'PMC5397534',
#  'PMC6949866',
#  'PMC2612543',
#  'PMC4199241',
#  'PMC2683948',
#  'PMC6455212',
#  'PMC4558759',
#  'PMC7106215',
#  'PMC7092902',
#  'PMC7126972',
#  'PMC7113865',
#  'PMC7104009',
#  'PMC6125322',
#  'PMC7097533',
#  'PMC7119692',
#  'PMC7149615',
#  'PMC7121782',
#  'PMC7126117',
#  'PMC7086920',
#  'PMC7087907',
#  'PMC7114303',
#  'PMC7120478',
#  'PMC7126349',
#  'PMC3924095',
#  'PMC7114485',
#  'PMC7115701',
#  'PMC7126777',
#  'PMC7126391',
#  'PMC5717090',
#  'PMC7067377',
#  'PMC5794838',
#  'PMC7091833',
#  'PMC2204037',
#  'PMC3892599',
#  'PMC3616288',
#  'PMC3310112',
#  'PMC7151966',
#  'PMC3322913',
#  'PMC7107995',
#  'PMC7108295',
#  'PMC7112129',
#  'PMC6504611',
#  'PMC7112547',
#  'PMC5725989',
#  'PMC7088712',
#  'PMC7094314',
#  'PMC5035092',
#  'PMC6356965',
#  'PMC4292534',
#  'PMC5462105',
#  'PMC7134187',
#  'PMC7126614',
#  'PMC7128414',
#  'PMC7095087',
#  'PMC7126097',
#  'PMC7089137',
#  'PMC7115277',
#  'PMC7107815',
#  'PMC7115684',
#  'PMC7146799',
#  'PMC7142029',
#  'PMC7108609',
#  'PMC5923478',
#  'PMC6590882',
#  'PMC4512304',
#  'PMC6555026',
#  'PMC5134239',
#  'PMC7109838',
#  'PMC7112925',
#  'PMC6941262',
#  'PMC7112096',
#  'PMC7125906',
#  'PMC7133760',
#  'PMC4439490',
#  'PMC3331808',
#  'PMC7130604',
#  'PMC7119310',
#  'PMC7137740',
#  'PMC7142681',
#  'PMC7113758',
#  'PMC7112918',
#  'PMC7090734',
#  'PMC4607778',
#  'PMC7107873',
#  'PMC7121921',
#  'PMC7149643',
#  'PMC6669519',
#  'PMC7115637',
#  'PMC7123247',
#  'PMC5812231',
#  'PMC7026628',
#  'PMC7086681',
#  'PMC6254255',
#  'PMC5865735',
#  'PMC7107162',
#  'PMC5801815',
#  'PMC5853440',
#  'PMC7089040',
#  'PMC5893353',
#  'PMC7115389',
#  'PMC7121444',
#  'PMC7108361',
#  'PMC7087820',
#  'PMC7112890',
#  'PMC2797526',
#  'PMC7152401',
#  'PMC4415223',
#  'PMC7086739',
#  'PMC7127485',
#  'PMC4224467',
#  'PMC2810402',
#  'PMC3320402',
#  'PMC7117270',
#  'PMC7117177',
#  'PMC7088545',
#  'PMC7115301',
#  'PMC7138071',
#  'PMC7079899',
#  'PMC3712877',
#  'PMC7121910',
#  'PMC2788226',
#  'PMC1462960',
#  'PMC6280386',
#  'PMC7115722',
#  'PMC6085545',
#  'PMC7123051',
#  'PMC4488679',
#  'PMC3502730',
#  'PMC7117012',
#  'PMC7115644',
#  'PMC4924831',
#  'PMC7149677',
#  'PMC3410596',
#  'PMC3414488',
#  'PMC3901151',
#  'PMC7127657',
#  'PMC7109704',
#  'PMC3942179',
#  'PMC7113756',
#  'PMC7131543',
#  'PMC7103404',
#  'PMC6385200',
#  'PMC3089605',
#  'PMC7131612',
#  'PMC7113668',
#  'PMC7088930',
#  'PMC7088313',
#  'PMC7122345',
#  'PMC6408101',
#  'PMC553849',
#  'PMC4495935',
#  'PMC5567081',
#  'PMC6805422',
#  'PMC5362214',
#  'PMC7109778',
#  'PMC7150093',
#  'PMC5896202',
#  'PMC7048180',
#  'PMC7123984',
#  'PMC5709983',
#  'PMC7097543',
#  'PMC1762333',
#  'PMC7094778',
#  'PMC3909712',
#  'PMC7122341',
#  'PMC7109991',
#  'PMC5360578',
#  'PMC5172477',
#  'PMC7075649',
#  'PMC3177209',
#  'PMC7115508',
#  'PMC7094296',
#  'PMC3217223',
#  'PMC3090357',
#  'PMC3348177',
#  'PMC4580468',
#  'PMC7123174',
#  'PMC7148697',
#  'PMC7108248',
#  'PMC7117002',
#  'PMC7111470',
#  'PMC7114942',
#  'PMC5382490',
#  'PMC7111340',
#  'PMC6466325',
#  'PMC3554583',
#  'PMC7129517',
#  'PMC3088723',
#  'PMC7104183',
#  'PMC6836755',
#  'PMC3086881',
#  'PMC4717660',
#  'PMC4835727',
#  'PMC6679648',
#  'PMC7094523',
#  'PMC7112551',
#  'PMC7125725',
#  'PMC5691643',
#  'PMC7130429',
#  'PMC7126161',
#  'PMC4256287',
#  'PMC7150256',
#  'PMC7128798',
#  'PMC7133876',
#  'PMC7047475',
#  'PMC4033317',
#  'PMC7111870',
#  'PMC6971912',
#  'PMC4642273',
#  'PMC7106266',
#  'PMC2864199',
#  'PMC552329',
#  'PMC7110630',
#  'PMC7046297',
#  'PMC7150135',
#  'PMC7138432',
#  'PMC3002947',
#  'PMC7135822',
#  'PMC6138378',
#  'PMC3163031',
#  'PMC7097100',
#  'PMC7149200',
#  'PMC4397715',
#  'PMC6929483',
#  'PMC7104192',
#  'PMC3812713',
#  'PMC7127454',
#  'PMC3913500',
#  'PMC3559034',
#  'PMC6232770',
#  'PMC6430897',
#  'PMC5872002',
#  'PMC4495409',
#  'PMC6499176',
#  'PMC7107480',
#  'PMC7126602',
#  'PMC6010623',
#  'PMC7088403',
#  'PMC7091376',
#  'PMC7086743',
#  'PMC4712828',
#  'PMC7108323',
#  'PMC7104601',
#  'PMC7106014',
#  'PMC6560178',
#  'PMC6963182',
#  'PMC7103727',
#  'PMC7080040',
#  'PMC7109453',
#  'PMC7118459',
#  'PMC7094248',
#  'PMC4037351',
#  'PMC7106046',
#  'PMC7121478',
#  'PMC3575307',
#  'PMC3953068',
#  'PMC2753892',
#  'PMC7134480',
#  'PMC7119477',
#  'PMC7111657',
#  'PMC7108193',
#  'PMC7130309',
#  'PMC7149976',
#  'PMC4073847',
#  'PMC7087747',
#  'PMC7113866',
#  'PMC3639867',
#  'PMC5359610',
#  'PMC7151772',
#  'PMC7120316',
#  'PMC7131297',
#  'PMC3229973',
#  'PMC7095922',
#  'PMC7112285',
#  'PMC7114834',
#  'PMC2852402',
#  'PMC7086925',
#  'PMC7092810',
#  'PMC7126267',
#  'PMC2853144',
#  'PMC7126624',
#  'PMC2984239',
#  'PMC7103373',
#  'PMC4710178',
#  'PMC5052702',
#  'PMC5788108',
#  'PMC7127715',
#  'PMC7094693',
#  'PMC7111424',
#  'PMC4376766',
#  'PMC7148736',
#  'PMC3618226',
#  'PMC7115804',
#  'PMC7115772',
#  'PMC3499540',
#  'PMC5421875',
#  'PMC5781002',
#  'PMC7094156',
#  'PMC3049855',
#  'PMC3291384',
#  'PMC1299207',
#  'PMC7108521',
#  'PMC7147863',
#  'PMC7150150',
#  'PMC7103114',
#  'PMC2893165',
#  'PMC2923618',
#  'PMC7095228',
#  'PMC7148905',
#  'PMC7125592',
#  'PMC4353893',
#  'PMC2589374',
#  'PMC7080095',
#  'PMC2274893',
#  'PMC7130208',
#  'PMC4393672',
#  'PMC6117295',
#  'PMC2790308',
#  'PMC7117614',
#  'PMC4929493',
#  'PMC4308662',
#  'PMC5115602',
#  'PMC7088734',
#  'PMC7108614',
#  'PMC3326065',
#  'PMC5407209',
#  'PMC2725959',
#  'PMC4382184',
#  'PMC7094391',
#  'PMC7096024',
#  'PMC7099897',
#  'PMC6985271',
#  'PMC7150332',
#  'PMC3086175',
#  'PMC7104954',
#  'PMC4093902',
#  'PMC6206643',
#  'PMC6341152',
#  'PMC7086814',
#  'PMC7089008',
#  'PMC3990711',
#  'PMC7110841',
#  'PMC3662671',
#  'PMC4488716',
#  'PMC7088392',
#  'PMC7105964',
#  'PMC7129930',
#  'PMC5850863',
#  'PMC7125865',
#  'PMC6518565',
#  'PMC4344680',
#  'PMC4876401',
#  'PMC5038994',
#  'PMC7119966',
#  'PMC7105198',
#  'PMC6499107',
#  'PMC7100063',
#  'PMC6950189',
#  'PMC5505021',
#  'PMC7114522',
#  'PMC4304971',
#  'PMC5580455',
#  'PMC7127616',
#  'PMC7126177',
#  'PMC4270245',
#  'PMC7112270',
#  'PMC7119992',
#  'PMC6207626',
#  'PMC4028814',
#  'PMC2824758',
#  'PMC6963271',
#  'PMC7123856',
#  'PMC7131109',
#  'PMC3832146',
#  'PMC7090873',
#  'PMC3168606',
#  'PMC7112255',
#  'PMC7107292',
#  'PMC6315547',
#  'PMC4822964',
#  'PMC7086806',
#  'PMC5139145',
#  'PMC2739295',
#  'PMC7127687',
#  'PMC7107954',
#  'PMC4625024',
#  'PMC2376094',
#  'PMC7086825',
#  'PMC7089173',
#  'PMC2846721',
#  'PMC7114826',
#  'PMC4236132',
#  'PMC6010046',
#  'PMC7148700',
#  'PMC7123903',
#  'PMC7121913',
#  'PMC3466995',
#  'PMC6163574',
#  'PMC5076476',
#  'PMC4899559',
#  'PMC6937528',
#  'PMC6408131',
#  'PMC7097425',
#  'PMC6935492',
#  'PMC7109808',
#  'PMC7126836',
#  'PMC7126907',
#  'PMC6710369',
#  'PMC7140287',
#  'PMC6613042',
#  'PMC5201231',
#  'PMC7106513',
#  'PMC7126309',
#  'PMC7124311',
#  'PMC7109913',
#  'PMC2823673',
#  'PMC3265307',
#  'PMC4445801',
#  'PMC7129717',
#  'PMC7108349',
#  'PMC7155167',
#  'PMC3438048',
#  'PMC5109220',
#  'PMC7111837',
#  'PMC7112379',
#  'PMC3447300',
#  'PMC6205447',
#  'PMC5888411',
#  'PMC7130274',
#  'PMC4150610',
#  'PMC7110250',
#  'PMC2830353',
#  'PMC3278842',
#  'PMC7117044',
#  'PMC3427567',
#  'PMC7132249',
#  'PMC7135803',
#  'PMC6589770',
#  'PMC7122328',
#  'PMC5850271',
#  'PMC7133932',
#  'PMC4012820',
#  'PMC6230768',
#  'PMC3447298',
#  'PMC4868018',
#  'PMC7110190',
#  'PMC7110471',
#  'PMC6111625',
#  'PMC5053637',
#  'PMC7140595',
#  'PMC7150011',
#  'PMC7121007',
#  'PMC3635991',
#  'PMC7087203',
#  'PMC7089229',
#  'PMC3217956',
#  'PMC7117049',
#  'PMC4374190',
#  'PMC7106353',
#  'PMC7122151',
#  'PMC7094237',
#  'PMC4037715',
#  'PMC5510245',
#  'PMC7127449',
#  'PMC5870463',
#  'PMC7131585',
#  'PMC7106285',
#  'PMC7091259',
#  'PMC7097825',
#  'PMC7148906',
#  'PMC7126853',
#  'PMC5034104',
#  'PMC3439358',
#  'PMC5907822',
#  'PMC5005348',
#  'PMC6471425',
#  'PMC7130792',
#  'PMC5533278',
#  'PMC7112663',
#  'PMC5294357',
#  'PMC7115388',
#  'PMC4322817',
#  'PMC7130340',
#  'PMC7147839',
#  'PMC7112094',
#  'PMC7135119',
#  'PMC4780752',
#  'PMC7146817',
#  'PMC2779236',
#  'PMC7110848',
#  'PMC7122420',
#  'PMC3534549',
#  'PMC7088224',
#  'PMC5729395',
#  'PMC7092873',
#  'PMC7149696',
#  'PMC2671596',
#  'PMC7148659',
#  'PMC2710004',
#  'PMC5572892',
#  'PMC5647739',
#  'PMC7114281',
#  'PMC7122061',
#  'PMC7097548',
#  'PMC3091864',
#  'PMC7121447',
#  'PMC7077254',
#  'PMC7114384',
#  ...}

# %%
cord_df[cord_df.pmcid=='PMC7114679']
# Out:
#         cord_uid                source_x  \
# 709226  31yznyut  Elsevier; Medline; PMC
#
#                                                    title  \
# 709226  Canine Coronavirus: Not Only an Enteric Pathogen
#
#                                                  abstract publish_time  \
# 709226  This article reviews the currently available l...   2011-09-29
#
#                                    journal  \
# 709226  Vet Clin North Am Small Anim Pract
#
#                                    authors  \
# 709226  Decaro, Nicola; Buonavoglia, Canio
#
#                                                       url       pmcid  \
# 709226  https://www.ncbi.nlm.nih.gov/pubmed/22041207/;...  PMC7114679
#
#                                                modalities
# 709226  pho pho mic.lig mic.lig mic.lig mic.lig pho ph...

# %%
cord_df.to_parquet('./2022-02-07-cord19-wmodalities.parquet')
